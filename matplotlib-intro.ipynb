# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %reload_ext autoreload
# %autoreload 2

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1**2

plt.plot(x_1, y_1)
plt.title('Days Squared Chart')
plt.xlabel('Days')
plt.ylabel('Days Squared')
# Out:
# Text(0, 0.5, 'Days Squared')

# %% [markdown]
# #### Print Multiple Plots

# %%
plt.subplot(1,2,1)
plt.plot(x_1, y_1, 'r')

plt.subplot(1,2,2)
plt.plot(x_1, y_1, 'b')

# %% [markdown]
# #### Using Figure Objects

# %%
fig_1 = plt.figure(figsize=(5,4), dpi=100)
axes_1 = fig_1.add_axes([0.1, 0.1, 0.9, 0.9])
axes_1.set_xlabel('Days')  # Corrected method name
axes_1.set_ylabel('Days Squared')
axes_1.set_title('Days Squared Chart')
axes_1.plot(x_1, y_1, label='x/x^2')
axes_1.plot(y_1, x_1, label='x^2/x')

# upper right: 1, upper left: 2, lower left: 3, lower right: 4,
# or supply a tuple of x & y from lower left
axes_1.legend(loc=0)

# %%
# Add one more chat into the existing charts
fig_1 = plt.figure(figsize=(5,4), dpi=100)
axes_1 = fig_1.add_axes([0.1, 0.1, 0.9, 0.9])
axes_1.set_xlabel('Days')  # Corrected method name
axes_1.set_ylabel('Days Squared')
axes_1.set_title('Days Squared Chart')
axes_1.plot(x_1, y_1, label='x/x^2')
axes_1.plot(y_1, x_1, label='x^2/x')

# upper right: 1, upper left: 2, lower left: 3, lower right: 4,
# or supply a tuple of x & y from lower left
axes_1.legend(loc=0)

axes_2 = fig_1.add_axes([0.45, 0.45, 0.4, 0.3])
axes_2.set_xlabel('Days')  # Corrected method name
axes_2.set_ylabel('Days Squared')
axes_2.set_title('Days Squared Chart')
axes_2.plot(x_1, y_1, 'r')

axes_2.text(0,40, 'Message')
# Out:
# Text(0, 40, 'Message')

# %% [markdown]
# #### SubPlots

# %%
fig_2, axes_2 = plt.subplots(figsize=(8,4), nrows=1, ncols=3)
plt.tight_layout()
axes_2[1].set_title('Plot 2')
axes_2[1].set_xlabel('X')
axes_2[1].set_xlabel('X Squared')
axes_2[1].plot(x_1, y_1)

# %% [markdown]
# #### Appearance Options

# %%
# Default colors (b: blue, g: green, r: red, c: cyan, m: magenta, y: yellow, k: black, w: white)
# color="0.75" creates a 75% gray
# you can use hexcodes color="#eeefff"
# you can use color names found bext like this color='burlywood'

fig_3 = plt.figure(figsize=(6,4))
axes_3 = fig_3.add_axes([0,0,1,1])
axes_3.plot(x_1, y_1, color='navy', alpha=.75, lw=2, ls='-.', marker='o', markersize=7,
            markerfacecolor='y', markeredgecolor='y', markeredgewidth=4)

axes_3.set_ylim([0,8])
axes_3.set_xlim([0,3])

axes_3.grid(True, color='0.6', dashes=(5,2,1,2))
axes_3.set_facecolor('#FAEBD7')

# %% [markdown]
# #### Save Visualization to a File

# %%
fig_3.savefig('first_plot_img.png')
