# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_1 = np.linspace(0,5,10)
y_1 = x_1**2
fig_1 = plt.figure(figsize=(5,4), dpi=100)
axes_1 = fig_1.add_axes([0.1, 0.1, 0.9, 0.9])

axes_1.text(0, 23, r'$\alpha \beta \sigma \omega \epsilon \mu \pi \theta \lambda$')

axes_1.text(0, 18, r'$\delta_1 \gamma^{ij} \sum_{i=0}^\infty x_i \frac{3}{4}$')

axes_1.text(0, 13, r'$\frac{8 - \frac{x}{5}}{8} \sqrt{9} \sin(\pi) \sqrt[3]{8} \acute a \div$')

axes_1.text(0, 8, r'$\bar a \hat a \vec a \overline {a} \lim_{x \to 2} f(x) = 5$')

axes_1.text(0, 3, r'$\geq \leq \ne$')

axes_1.plot(x_1, y_1)
