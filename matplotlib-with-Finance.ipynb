# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d 

import mplfinance as mpf

# %reload_ext autoreload
# %autoreload 2

# %%
goog_df =  pd.read_csv(r'..\datasets\Yahoo-Finance-GOOG.csv', index_col=0, parse_dates=True)
goog_df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-04-12  107.389999  107.586998  104.970001  105.220001  105.220001
# 2023-04-13  106.470001  108.264999  106.440002  108.190002  108.190002
# 2023-04-14  107.690002  109.580002  107.589996  109.459999  109.459999
# 2023-04-17  105.430000  106.709999  105.320000  106.419998  106.419998
# 2023-04-18  107.000000  107.050003  104.779999  105.120003  105.120003
#
#               Volume
# Date
# 2023-04-12  22761600
# 2023-04-13  21650700
# 2023-04-14  20758700
# 2023-04-17  29043400
# 2023-04-18  17641400

# %%
goog_df.index.name = 'Date'

mpf.plot(goog_df, type='candle')

# %%
mpf.plot(goog_df, type='line')

# %%
mpf.plot(goog_df, type='ohlc', mav=4)

# %%
mpf.plot(goog_df, type='ohlc', mav=(3,5,7), volume=True, show_nontrading=True)
